# %% [markdown]
# # Задача 1.1.
# # Выведите на консоль с помощью индексации строки, последовательно: первый трек, последний, второй, второй с конца

# %%
my_favorite_songs = 'Waste a Moment, Stayingg\' Alive, A Sorta Fairytale, Start Me Up, New Salvation'
print(my_favorite_songs[:14])
print(my_favorite_songs[-13:-1])
print(my_favorite_songs[16:31])
print(my_favorite_songs[-26:-15])
# Out:
# Waste a Moment
# New Salvatio
# Stayingg' Alive
# Start Me Up
